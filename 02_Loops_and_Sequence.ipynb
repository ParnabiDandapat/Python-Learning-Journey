# %% [markdown]
# <a href="https://colab.research.google.com/github/ParnabiDandapat/Python-Learning-Journey/blob/main/02_Loops_and_Sequence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
